# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# Step 1: Read the dataset

# %%
import pandas as pd
df = pd.read_csv("50_Startups.csv")
df
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#         RND      ADMIN        MKT       STATE    PROFIT
# 45  1000.23  124153.04    1903.93    New York  64926.08
# 46  1315.46  115816.21  297114.46     Florida  49490.75
# 47     0.00  135426.92       0.00  California  42559.73
# 48   542.05   51743.15       0.00    New York  35673.41
# 49     0.00  116983.80   45173.06  California  14681.40

# %% [markdown]
# Step 2 : Basic Data Quality Checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Step 3 : Separate X(RND,ADMIN,MKT) and Y(PROFIT)
#
# PROFIT ~ RND,ADMIN,MKT
#
# PROFIT_pred = B0 + B1xRND + B2xADMIN + B3xMKT

# %%
X = df[['RND', 'ADMIN', 'MKT']]
Y = df[['PROFIT']]

# %%
X.head()
# Out:
#          RND      ADMIN        MKT
# 0  165349.20  136897.80  471784.10
# 1  162597.70  151377.59  443898.53
# 2  153441.51  101145.55  407934.54
# 3  144372.41  118671.85  383199.62
# 4  142107.34   91391.77  366168.42

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# Step 4 : Build the linear regression model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([50122.19298987])

# %%
model.coef_
# Out:
# array([[ 0.80571505, -0.02681597,  0.02722806]])

# %%
X.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT'], dtype='object')

# %% [markdown]
# PROFIT_pred = 50122.19 + 0.8057xRND - 0.0268xADMIN + 0.0272xMKT
#
# RND is having highest coefficient , Hence more i spend in RND more will be the profit
#
# Step 5 : Evaluate the model

# %%
# R2 score
model.score(X, Y)
# Out:
# 0.9507459940683246

# %%
ypred = model.predict(X)
ypred[0:5]
# Out:
# array([[192521.25289008],
#        [189156.76823227],
#        [182147.2790962 ],
#        [173696.70002553],
#        [172139.51418327]])

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error, r2_score

# %%
def evaluate_model(model, X, Y):
    ypred = model.predict(X)
    mse = mean_squared_error(Y, ypred)
    rmse = mse**(1/2)
    mae = mean_absolute_error(Y, ypred)
    mape = mean_absolute_percentage_error(Y, ypred)
    r2 = r2_score(Y, ypred)
    # Print all above results
    print(f'Mean Squared Error (MSE): {mse:.2f}')
    print(f'Root Mean Squared Error (RMSE) : {rmse:.2f}')
    print(f'Mean Absolute Error (MAE) : {mae:.2f}')
    print(f'Mean ABsolute Percetage Error (MAPE) : {mape*100:.2f} %')
    print(f'R2 score : {r2:.4f}')

# %%
evaluate_model(model, X, Y)
# Out:
# Mean Squared Error (MSE): 78417126.02
# Root Mean Squared Error (RMSE) : 8855.34
# Mean Absolute Error (MAE) : 6471.45
# Mean ABsolute Percetage Error (MAPE) : 10.60 %
# R2 score : 0.9507

# %% [markdown]
# Because above model has r2 score of 0.9507 > 0.8 hence above model is good model
#
# Step 6 : Out of Sample Prediction

# %%
X.values[0:5]
# Out:
# array([[165349.2 , 136897.8 , 471784.1 ],
#        [162597.7 , 151377.59, 443898.53],
#        [153441.51, 101145.55, 407934.54],
#        [144372.41, 118671.85, 383199.62],
#        [142107.34,  91391.77, 366168.42]])

# %%
X.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT'], dtype='object')

# %%
rnd = 100000
admin = 40000
mkt = 35000
xnew = [[rnd, admin, mkt]]
pred = model.predict(xnew)[0][0]
print(f'The Estimated Profit is : {pred:.2f}')
# Out:
# The Estimated Profit is : 130574.04
# c:\Vaishali\DataScience\Machine Learning\MLVSCode\repository\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
